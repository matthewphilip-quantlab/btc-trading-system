# %%
# %pip install -qU "numpy==1.26.4" "tensorflow-macos==2.15.*" "tensorflow-metal"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np, tensorflow as tf
print("NumPy:", np.__version__, "| TF:", tf.__version__)
# Out:
# /opt/anaconda3/envs/tf311/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# NumPy: 1.26.4 | TF: 2.16.2
